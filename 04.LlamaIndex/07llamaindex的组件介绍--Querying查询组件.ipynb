# %%
 from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.langchain import LangChainLLM
from langchain_community.embeddings import DashScopeEmbeddings
from langchain_openai.chat_models import ChatOpenAI
from Config.load_key import open_key
from Config.load_key import base_model
from Config.load_key import base_url

model = ChatOpenAI(
    model=base_model,
    base_url=base_url,
    api_key=open_key
)

#初始化通义千问的模型
embed_model = DashScopeEmbeddings(
    dashscope_api_key=open_key,
    model='text-embedding-v2'
)

#加载参考数据
documents = SimpleDirectoryReader('./Source').load_data()
index = VectorStoreIndex.from_documents(documents, embed_model=embed_model)

#将langchain的LLm封装成LLamaindex的llm
llama_model = LangChainLLM(
    llm=model
)
#构建检索引擎 query_engine支持单词， chat Engine支持多轮对话
query_engine = index.as_query_engine(
    llm=llama_model
)

response = query_engine.query('怎么退款？')
response
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
#       2 from llama_index.llms.langchain import LangChainLLM
#       3 from langchain_community.embeddings import DashScopeEmbeddings
#       4 from langchain_openai.chat_models import ChatOpenAI
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\__init__.py:26
#      22 from llama_index.core.embeddings.mock_embed_model import MockEmbedding
#      24 # indices
#      25 # loading
# ---> 26 from llama_index.core.indices import (
#      27     ComposableGraph,
#      28     DocumentSummaryIndex,
#      29     GPTDocumentSummaryIndex,
#      30     GPTKeywordTableIndex,
#      31     GPTListIndex,
#      32     GPTRAKEKeywordTableIndex,
#      33     GPTSimpleKeywordTableIndex,
#      34     GPTTreeIndex,
#      35     GPTVectorStoreIndex,
#      36     KeywordTableIndex,
#      37     KnowledgeGraphIndex,
#      38     ListIndex,
#      39     PropertyGraphIndex,
#      40     RAKEKeywordTableIndex,
#      41     SimpleKeywordTableIndex,
#      42     SummaryIndex,
#      43     TreeIndex,
#      44     VectorStoreIndex,
#      45     load_graph_from_storage,
#      46     load_index_from_storage,
#      47     load_indices_from_storage,
#      48 )
#      50 # structured
#      51 from llama_index.core.indices.common.struct_store.base import (
#      52     SQLDocumentContextBuilder,
#      53 )
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\indices\__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ----> 4 from llama_index.core.indices.composability.graph import ComposableGraph
#       5 from llama_index.core.indices.document_summary import (
#       6     DocumentSummaryIndex,
#       7     GPTDocumentSummaryIndex,
#       8 )
#       9 from llama_index.core.indices.document_summary.base import DocumentSummaryIndex
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\indices\composability\__init__.py:3
#       1 """This module contains all classes used for composing graphs over indices."""
# ----> 3 from llama_index.core.indices.composability.graph import ComposableGraph
#       5 __all__ = ["ComposableGraph"]
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\indices\composability\graph.py:7
#       5 from llama_index.core.base.base_query_engine import BaseQueryEngine
#       6 from llama_index.core.data_structs.data_structs import IndexStruct
# ----> 7 from llama_index.core.indices.base import BaseIndex
#       8 from llama_index.core.schema import (
#       9     IndexNode,
#      10     NodeRelationship,
#      11     ObjectType,
#      12     RelatedNodeInfo,
#      13 )
#      14 from llama_index.core.storage.storage_context import StorageContext
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\indices\base.py:10
#       8 from llama_index.core.base.base_retriever import BaseRetriever
#       9 from llama_index.core.callbacks.base import CallbackManager
# ---> 10 from llama_index.core.chat_engine.types import BaseChatEngine, ChatMode
#      11 from llama_index.core.data_structs.data_structs import IndexStruct
#      12 from llama_index.core.ingestion import run_transformations, arun_transformations
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\chat_engine\__init__.py:1
# ----> 1 from llama_index.core.chat_engine.condense_plus_context import (
#       2     CondensePlusContextChatEngine,
#       3 )
#       4 from llama_index.core.chat_engine.condense_question import (
#       5     CondenseQuestionChatEngine,
#       6 )
#       7 from llama_index.core.chat_engine.context import ContextChatEngine
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\chat_engine\condense_plus_context.py:17
#      12 from llama_index.core.base.response.schema import (
#      13     AsyncStreamingResponse,
#      14     StreamingResponse,
#      15 )
#      16 from llama_index.core.callbacks import CallbackManager, trace_method
# ---> 17 from llama_index.core.chat_engine.types import (
#      18     AgentChatResponse,
#      19     BaseChatEngine,
#      20     StreamingAgentChatResponse,
#      21     ToolOutput,
#      22 )
#      23 from llama_index.core.indices.base_retriever import BaseRetriever
#      24 from llama_index.core.indices.query.schema import QueryBundle
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\chat_engine\types.py:19
#      13 from llama_index.core.base.llms.types import (
#      14     ChatMessage,
#      15     ChatResponseAsyncGen,
#      16     ChatResponseGen,
#      17 )
#      18 from llama_index.core.base.response.schema import Response, StreamingResponse
# ---> 19 from llama_index.core.memory import BaseMemory
#      20 from llama_index.core.schema import NodeWithScore
#      21 from llama_index.core.tools import ToolOutput
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\memory\__init__.py:6
#       4 from llama_index.core.memory.vector_memory import VectorMemory
#       5 from llama_index.core.memory.simple_composable_memory import SimpleComposableMemory
# ----> 6 from llama_index.core.memory.memory import Memory, BaseMemoryBlock, InsertMethod
#       7 from llama_index.core.memory.memory_blocks import (
#       8     StaticMemoryBlock,
#       9     VectorMemoryBlock,
#      10     FactExtractionMemoryBlock,
#      11 )
#      13 __all__ = [
#      14     "BaseMemory",
#      15     "Memory",
#    (...)     25     "VectorMemory",
#      26 ]
#
# File F:\work\cs\AI\AI Agent\venv\Lib\site-packages\llama_index\core\memory\memory.py:5
#       3 from abc import abstractmethod
#       4 from enum import Enum
# ----> 5 from sqlalchemy.ext.asyncio import AsyncEngine
#       6 from typing import (
#       7     Any,
#       8     Callable,
#    (...)     16     cast,
#      17 )
#      19 from llama_index.core.async_utils import asyncio_run
#
# File F:\work\cs\AI\AI Agent\10.新闻头条---fastApi\venv\Lib\site-packages\sqlalchemy\ext\asyncio\__init__.py:18
#      16 from .result import AsyncScalarResult as AsyncScalarResult
#      17 from .result import AsyncTupleResult as AsyncTupleResult
# ---> 18 from .scoping import async_scoped_session as async_scoped_session
#      19 from .session import async_object_session as async_object_session
#      20 from .session import async_session as async_session
#
# File F:\work\cs\AI\AI Agent\10.新闻头条---fastApi\venv\Lib\site-packages\sqlalchemy\ext\asyncio\scoping.py:24
#      21 from typing import TypeVar
#      22 from typing import Union
# ---> 24 from .session import _AS
#      25 from .session import async_sessionmaker
#      26 from .session import AsyncSession
#
# File F:\work\cs\AI\AI Agent\10.新闻头条---fastApi\venv\Lib\site-packages\sqlalchemy\ext\asyncio\session.py:35
#      33 from .result import AsyncScalarResult
#      34 from ... import util
# ---> 35 from ...orm import close_all_sessions as _sync_close_all_sessions
#      36 from ...orm import object_session
#      37 from ...orm import Session
#
# File F:\work\cs\AI\AI Agent\10.新闻头条---fastApi\venv\Lib\site-packages\sqlalchemy\orm\__init__.py:21
#      18 from typing import Any
#      20 from . import exc as exc
# ---> 21 from . import mapper as mapperlib
#      22 from . import strategy_options as strategy_options
#      23 from ._orm_constructors import _mapper_fn as mapper
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1334, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1019, in _LoaderBasics.exec_module(self, module)
#    1017 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap_external>:1116, in SourceLoader.get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1215, in FileLoader.get_data(self, path)
#    1211 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# Setting全局设置

# %%
from llama_index.core import Settings, VectorStoreIndex, SimpleDirectoryReader
from llama_index.embeddings.langchain import LangchainEmbedding
from langchain_community.embeddings import DashScopeEmbeddings
from Config.load_key import open_key
from Config.load_key import base_model
from Config.load_key import base_url
model = ChatOpenAI(
    model=base_model,
    base_url=base_url,
    api_key=open_key
)

#初始化通义千问的模型
embed_model = LangchainEmbedding(DashScopeEmbeddings(
    dashscope_api_key=open_key,
    model='text-embedding-v2'
))
Settings.llm = model
Settings.embed_model = embed_model

#加载参考数据
documents = SimpleDirectoryReader('./Source').load_data()
index = VectorStoreIndex.from_documents(documents)

query_engine = index.as_query_engine()

response = query_engine.query('怎么退款？')
response
